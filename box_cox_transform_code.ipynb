# %% [markdown]
# <a href="https://colab.research.google.com/github/sysiphe0/exercise_ml/blob/main/box_cox_transform_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### 참고(출처) : Carl's Tech Bolg (https://wotres.tistory.com/)

# %%
# BOX-COX 변환은 정규분포가 아닌 자료를, 정규분포로 변환하기 위해 사용됨 (lambda값 통해 조정)
from scipy import stats
import matplotlib.pyplot as plt

fig = plt.figure()
# 2행 1열의 세부 그림장 생성
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(133)

# log gamma continuous random variable 생성
x = stats.loggamma.rvs(5, size=500) + 5
# Q-Q 플롯 그리기
prob = stats.probplot(x, dist=stats.norm, plot=ax1)
ax1.set_title('Q-Q original x')

# box-cox 변환 사용 => 조그 더 정규화됨
x_trans, optimal_lambda = stats.boxcox(x)
prob = stats.probplot(x_trans, dist=stats.norm, plot=ax2)
ax2.set_title('Q-Q box-cox-transiation')
plt.show()

# box-cox 최적의 lambda 값 찾는법
print('최적의 람다값 : ', optimal_lambda)
# Out:
# 최적의 람다값 :  3.3310508130278103
